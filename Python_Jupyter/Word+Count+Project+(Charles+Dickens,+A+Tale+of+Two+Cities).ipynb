# %%
>>> import collections
>>> file = open(r"C:\Users\asburysean\Downloads\word_cloud (2)\word_cloud\98-0.txt", encoding="utf8")
>>> fileStopWords = open(r"C:\Users\asburysean\Downloads\word_cloud (2)\word_cloud\stopwords", encoding="utf8")
>>> print('about to set stop words:')
>>> wordcount={}
>>> stopwords={}
>>> stopwords = fileStopWords.read().lower().split()
>>> for i in stopwords:
...     print(i)
>>> print(len(stopwords))
>>> for word in file.read().lower().split():
...     word = word.replace(".","")
...     word = word.replace(",","")
...     word = word.replace("/'","")
...     word = word.replace(u"\u201C","")
...     if word not in stopwords:
...             if word not in wordcount:
...                     wordcount[word] = 1
...             else:
...                     wordcount[word] += 1
...
>>> d = collections.Counter(wordcount)
>>> for word, count in d.most_common(10):
...     print(word, ": ", count)
...
# Out:
# about to set stop words:
# a
# about
# above
# after
# again
# against
# all
# am
# an
# and
# any
# are
# aren't
# as
# at
# be
# because
# been
# before
# being
# below
# between
# both
# but
# by
# can
# can't
# cannot
# com
# could
# couldn't
# did
# didn't
# do
# does
# doesn't
# doing
# don't
# down
# during
# each
# else
# ever
# few
# for
# from
# further
# get
# had
# hadn't
# has
# hasn't
# have
# haven't
# having
# he
# he'd
# he'll
# he's
# her
# here
# here's
# hers
# herself
# him
# himself
# his
# how
# how's
# http
# i
# i'd
# i'll
# i'm
# i've
# if
# in
# into
# is
# isn't
# it
# it's
# its
# itself
# just
# k
# let's
# like
# me
# more
# most
# mustn't
# my
# myself
# no
# nor
# not
# of
# off
# on
# once
# only
# or
# other
# ought
# our
# ours
# ourselves
# out
# over
# own
# r
# same
# shall
# shan't
# she
# she'd
# she'll
# she's
# should
# shouldn't
# so
# some
# such
# than
# that
# that's
# the
# their
# theirs
# them
# themselves
# then
# there
# there's
# ...
